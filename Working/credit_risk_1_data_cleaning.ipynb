# %% [markdown]
# # Demo_Credit_Risk_Analysis

# %% [markdown]
# ## Methodology (Deliverable 1 & 2):
# **This notebook executes Exploritory Data Analysis and Data Cleaning as described below. This notebook end with the saving of the clean_loans_df as a csv file for follow-on use in preprocessing.**
# * Exploritory Data Analysis and Data Cleaning (remove or impute null values)
#
# * Feature selection / engineering:
#     - Drop columns that provide no usefull information for ML
#     - Drop (or impute) rows with missing values
#     - Examine the target variable (loan_status) and reclassify values as "high risk" and "low risk" <br><br>
#
# * Save resulting dataframe (clean_loans_df) as a csv file for use by all/others<br><br>
# Note: The result of feature selection / engineering and data cleaning was the trasformation of a dataset from shape of 115,674, 144 to one of 71,027, 76. This is a loss of 68 columns and 44,648 rows of data

# %% [markdown]
# ## Import Libraries
# Note a new python 3.7 evnironment called mlenv was created for this analysis

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sklearn dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report

from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# imbalanced-learn dependencies
from imblearn.metrics import classification_report_imbalanced
from imblearn.over_sampling import RandomOverSampler

from imblearn.over_sampling import SMOTE

from imblearn.under_sampling import ClusterCentroids
from imblearn.under_sampling import RandomUnderSampler

from imblearn.combine import SMOTEENN

# %% [markdown]
# ## Read in the CSV file

# %%
# read csv 
# note: the first row is just a comment - it will be skipped (skiprows=1)
# the last two rows are comments - they will be skipped [:-2]
file_path = Path('./Data/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path, skiprows=1)[:-2]
df
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0       NaN        NaN    20000.0      20000.0          20000.0   60 months
# 1       NaN        NaN    21225.0      21225.0          21225.0   60 months
# 2       NaN        NaN     5000.0       5000.0           5000.0   36 months
# 3       NaN        NaN    20000.0      20000.0          20000.0   36 months
# 4       NaN        NaN    12000.0      12000.0          12000.0   60 months
# ...     ...        ...        ...          ...              ...         ...
# 115670  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 115671  NaN        NaN     6000.0       6000.0           6000.0   36 months
# 115672  NaN        NaN    16000.0      16000.0          16000.0   36 months
# 115673  NaN        NaN    16000.0      16000.0          16000.0   60 months
# 115674  NaN        NaN    29250.0      29250.0          29250.0   60 months
#
#        int_rate  installment grade sub_grade  ...  \
# 0        17.19%       499.10     C        C5  ...
# 1        14.74%       502.05     C        C2  ...
# 2        17.97%       180.69     D        D1  ...
# 3         8.19%       628.49     A        A4  ...
# 4        15.57%       289.09     C        C3  ...
# ...         ...          ...   ...       ...  ...
# 115670   13.56%       169.83     C        C1  ...
# 115671    6.46%       183.79     A        A1  ...
# 115672   16.14%       563.62     C        C4  ...
# 115673   11.31%       350.36     B        B3  ...
# 115674   18.94%       757.80     D        D2  ...
#
#        orig_projected_additional_accrued_interest  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 115670                                        NaN
# 115671                                        NaN
# 115672                                        NaN
# 115673                                        NaN
# 115674                                        NaN
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 115670                            NaN                          NaN
# 115671                            NaN                          NaN
# 115672                            NaN                          NaN
# 115673                            NaN                          NaN
# 115674                            NaN                          NaN
#
#         debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 0                          N                       NaN               NaN
# 1                          N                       NaN               NaN
# 2                          N                       NaN               NaN
# 3                          N                       NaN               NaN
# 4                          N                       NaN               NaN
# ...                      ...                       ...               ...
# 115670                     N                       NaN               NaN
# 115671                     N                       NaN               NaN
# 115672                     N                       NaN               NaN
# 115673                     N                       NaN               NaN
# 115674                     N                       NaN               NaN
#
#        settlement_date settlement_amount  settlement_percentage  \
# 0                  NaN               NaN                    NaN
# 1                  NaN               NaN                    NaN
# 2                  NaN               NaN                    NaN
# 3                  NaN               NaN                    NaN
# 4                  NaN               NaN                    NaN
# ...                ...               ...                    ...
# 115670             NaN               NaN                    NaN
# 115671             NaN               NaN                    NaN
# 115672             NaN               NaN                    NaN
# 115673             NaN               NaN                    NaN
# 115674             NaN               NaN                    NaN
#
#         settlement_term
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 115670              NaN
# 115671              NaN
# 115672              NaN
# 115673              NaN
# 115674              NaN
#
# [115675 rows x 144 columns]

# %% [markdown]
# # Exploritory Data Analaysis (EDA)

# %%
number_columns = df.shape[1]
print(f"There were {number_columns} columns in the csv file")
# there were 144 columns in the csv file
# Out:
# There were 144 columns in the csv file

# %% [markdown]
# ## Data Cleaning & Feature Selection

# %%
# Note: Columns were screened by stakeholder down to the following list
columns = [
    "loan_amnt", "int_rate", "installment", "home_ownership",
    "annual_inc", "verification_status", "issue_d", "loan_status",
    "pymnt_plan", "dti", "delinq_2yrs", "inq_last_6mths",
    "open_acc", "pub_rec", "revol_bal", "total_acc",
    "initial_list_status", "out_prncp", "out_prncp_inv", "total_pymnt",
    "total_pymnt_inv", "total_rec_prncp", "total_rec_int", "total_rec_late_fee",
    "recoveries", "collection_recovery_fee", "last_pymnt_amnt", "next_pymnt_d",
    "collections_12_mths_ex_med", "policy_code", "application_type", "acc_now_delinq",
    "tot_coll_amt", "tot_cur_bal", "open_acc_6m", "open_act_il",
    "open_il_12m", "open_il_24m", "mths_since_rcnt_il", "total_bal_il",
    "il_util", "open_rv_12m", "open_rv_24m", "max_bal_bc",
    "all_util", "total_rev_hi_lim", "inq_fi", "total_cu_tl",
    "inq_last_12m", "acc_open_past_24mths", "avg_cur_bal", "bc_open_to_buy",
    "bc_util", "chargeoff_within_12_mths", "delinq_amnt", "mo_sin_old_il_acct",
    "mo_sin_old_rev_tl_op", "mo_sin_rcnt_rev_tl_op", "mo_sin_rcnt_tl", "mort_acc",
    "mths_since_recent_bc", "mths_since_recent_inq", "num_accts_ever_120_pd", "num_actv_bc_tl",
    "num_actv_rev_tl", "num_bc_sats", "num_bc_tl", "num_il_tl",
    "num_op_rev_tl", "num_rev_accts", "num_rev_tl_bal_gt_0",
    "num_sats", "num_tl_120dpd_2m", "num_tl_30dpd", "num_tl_90g_dpd_24m",
    "num_tl_op_past_12m", "pct_tl_nvr_dlq", "percent_bc_gt_75", "pub_rec_bankruptcies",
    "tax_liens", "tot_hi_cred_lim", "total_bal_ex_mort", "total_bc_limit",
    "total_il_high_credit_limit", "hardship_flag", "debt_settlement_flag"
]

target = ["loan_status"]

# %%
print(f" We will examine {len(columns)} of the original {number_columns} columns")
# Out:
#  We will examine 86 of the original 144 columns

# %%
# Get just the "columns" above
loans_df = df.loc[:, columns].copy()
loans_df.shape
# Out:
# (115675, 86)

# %% [markdown]
# ### Feature Selection: Drop columns with where all values are null

# %%
# Drop the null columns where all values are null
loans_df = loans_df.dropna(axis='columns', how='all')
loans_df.shape

# none were dropped for this dataframe
# Out:
# (115675, 86)

# %% [markdown]
# ### Data Clean: Examine dtypes

# %%
# examine datatypes
loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115675 entries, 0 to 115674
# Data columns (total 86 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   115675 non-null  float64
#  1   int_rate                    115675 non-null  object
#  2   installment                 115675 non-null  float64
#  3   home_ownership              115675 non-null  object
#  4   annual_inc                  115675 non-null  float64
#  5   verification_status         115675 non-null  object
#  6   issue_d                     115675 non-null  object
#  7   loan_status                 115675 non-null  object
#  8   pymnt_plan                  115675 non-null  object
#  9   dti                         115418 non-null  float64
#  10  delinq_2yrs                 115675 non-null  float64
#  11  inq_last_6mths              115675 non-null  float64
#  12  open_acc                    115675 non-null  float64
#  13  pub_rec                     115675 non-null  float64
#  14  revol_bal                   115675 non-null  float64
#  15  total_acc                   115675 non-null  float64
#  16  initial_list_status         115675 non-null  object
#  17  out_prncp                   115675 non-null  float64
#  18  out_prncp_inv               115675 non-null  float64
#  19  total_pymnt                 115675 non-null  float64
#  20  total_pymnt_inv             115675 non-null  float64
#  21  total_rec_prncp             115675 non-null  float64
#  22  total_rec_int               115675 non-null  float64
#  23  total_rec_late_fee          115675 non-null  float64
#  24  recoveries                  115675 non-null  float64
#  25  collection_recovery_fee     115675 non-null  float64
#  26  last_pymnt_amnt             115675 non-null  float64
#  27  next_pymnt_d                113477 non-null  object
#  28  collections_12_mths_ex_med  115675 non-null  float64
#  29  policy_code                 115675 non-null  float64
#  30  application_type            115675 non-null  object
#  31  acc_now_delinq              115675 non-null  float64
#  32  tot_coll_amt                115675 non-null  float64
#  33  tot_cur_bal                 115675 non-null  float64
#  34  open_acc_6m                 115675 non-null  float64
#  35  open_act_il                 115675 non-null  float64
#  36  open_il_12m                 115675 non-null  float64
#  37  open_il_24m                 115675 non-null  float64
#  38  mths_since_rcnt_il          112158 non-null  float64
#  39  total_bal_il                115675 non-null  float64
#  40  il_util                     98356 non-null   float64
#  41  open_rv_12m                 115675 non-null  float64
#  42  open_rv_24m                 115675 non-null  float64
#  43  max_bal_bc                  115675 non-null  float64
#  44  all_util                    115651 non-null  float64
#  45  total_rev_hi_lim            115675 non-null  float64
#  46  inq_fi                      115675 non-null  float64
#  47  total_cu_tl                 115675 non-null  float64
#  48  inq_last_12m                115675 non-null  float64
#  49  acc_open_past_24mths        115675 non-null  float64
#  50  avg_cur_bal                 115668 non-null  float64
#  51  bc_open_to_buy              114352 non-null  float64
#  52  bc_util                     114297 non-null  float64
#  53  chargeoff_within_12_mths    115675 non-null  float64
#  54  delinq_amnt                 115675 non-null  float64
#  55  mo_sin_old_il_acct          112158 non-null  float64
#  56  mo_sin_old_rev_tl_op        115675 non-null  float64
#  57  mo_sin_rcnt_rev_tl_op       115675 non-null  float64
#  58  mo_sin_rcnt_tl              115675 non-null  float64
#  59  mort_acc                    115675 non-null  float64
#  60  mths_since_recent_bc        114417 non-null  float64
#  61  mths_since_recent_inq       101318 non-null  float64
#  62  num_accts_ever_120_pd       115675 non-null  float64
#  63  num_actv_bc_tl              115675 non-null  float64
#  64  num_actv_rev_tl             115675 non-null  float64
#  65  num_bc_sats                 115675 non-null  float64
#  66  num_bc_tl                   115675 non-null  float64
#  67  num_il_tl                   115675 non-null  float64
#  68  num_op_rev_tl               115675 non-null  float64
#  69  num_rev_accts               115675 non-null  float64
#  70  num_rev_tl_bal_gt_0         115675 non-null  float64
#  71  num_sats                    115675 non-null  float64
#  72  num_tl_120dpd_2m            112529 non-null  float64
#  73  num_tl_30dpd                115675 non-null  float64
#  74  num_tl_90g_dpd_24m          115675 non-null  float64
#  75  num_tl_op_past_12m          115675 non-null  float64
#  76  pct_tl_nvr_dlq              115675 non-null  float64
#  77  percent_bc_gt_75            114346 non-null  float64
#  78  pub_rec_bankruptcies        115675 non-null  float64
#  79  tax_liens                   115675 non-null  float64
#  80  tot_hi_cred_lim             115675 non-null  float64
#  81  total_bal_ex_mort           115675 non-null  float64
#  82  total_bc_limit              115675 non-null  float64
#  83  total_il_high_credit_limit  115675 non-null  float64
#  84  hardship_flag               115675 non-null  object
#  85  debt_settlement_flag        115675 non-null  object
# dtypes: float64(75), object(11)
# memory usage: 75.9+ MB

# %% [markdown]
# ### Feature Selection: Drop columns with just one value
# (columns with just one value have no variability / additional information to train on)

# %%
# list comprehension for columns with just one value
# [expression, for column in columns, where conditional is true]
# view the columns before dropping
just_one_value = [col for col in loans_df.columns if (loans_df[col].value_counts().count() == 1)]
just_one_value
# Out:
# ['pymnt_plan',
#  'recoveries',
#  'collection_recovery_fee',
#  'policy_code',
#  'acc_now_delinq',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'tax_liens',
#  'hardship_flag',
#  'debt_settlement_flag']

# %%
# drop columns in just_one_value
loans_df = loans_df.drop(columns=just_one_value)
loans_df.shape
# Out:
# (115675, 76)

# %% [markdown]
# ### Data Cleaning: drop rows with missing values

# %%
# Use loans_df[column].isnull().sum() within list comprehension
# [expression, for column in columns, where conditional is true]
col_with_missing_values = [print(column, loans_df[column].isnull().sum()) for column in loans_df.columns if df[column].isnull().sum() >0 ]
print("\n", f"There are {len(col_with_missing_values)} columms that have rows with missing values")
# Out:
# dti 257
# next_pymnt_d 2198
# mths_since_rcnt_il 3517
# il_util 17319
# all_util 24
# avg_cur_bal 7
# bc_open_to_buy 1323
# bc_util 1378
# mo_sin_old_il_acct 3517
# mths_since_recent_bc 1258
# mths_since_recent_inq 14357
# percent_bc_gt_75 1329
#
#  There are 12 columms that have rows with missing values

# %%
# visualize missing values using a heatmap
# I am using seaborn which was imported as sns
plt.figure(figsize=(20,10))
sns.heatmap(loans_df.isnull(), cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Note: the columns it_uti and mths_since_recent_inq have many more missing values than other columns it might be best to drop those columns then to drop rows where this column has missing values. Another option would be to impute (replace) missing values with a value like the column average/mean. This would be something to discuss with the stakeholder. I am going to exam which preserves the most high_risk loans and choose that option. check after dropping those loans with loan_status of "Issued". Then check

# %%
# drop it_util (since il_util has 17319 missing values) and mnths_since_recent_bc (since mths_since_recent_inq has 14357 missing values)
loans_df =loans_df.drop(columns=['il_util', 'mths_since_recent_inq'])

# %%
# Drop rows with null values
loans_df = loans_df.dropna(how="any")
loans_df.shape
# Out:
# (108487, 74)

# %% [markdown]
# ### Feature selection: Examine the target variable (loan_status) and reclassify values as "high risk" and "low risk"

# %%
# examine the valvues for the target variable "loan_status"
loans_df['loan_status'].value_counts()
# Out:
# Current               89971
# Issued                18042
# In Grace Period         219
# Late (16-30 days)       132
# Late (31-120 days)      123
# Name: loan_status, dtype: int64

# %% [markdown]
# Note: loans with a loan_status of "Issued" have not been in existance long enough to determine a true status (i.e., these have been recently issues and there has not been time for the lender to make a payment (and be "Current") or not make a required payment (and be "In Grace Period", or one of the two "Late" values)
# Therefore rows with a loan_status of "Issued" will be removed.

# %%
# Remove the `Issued` loan status
issued_mask = df['loan_status'] != 'Issued'
loans_df = loans_df.loc[issued_mask]

# examine the result (those loans with other than "Issued" status)
loans_df['loan_status'].value_counts()
# Out:
# Current               89971
# In Grace Period         219
# Late (16-30 days)       132
# Late (31-120 days)      123
# Name: loan_status, dtype: int64

# %%
# Convert the target column values to low_risk and high_risk based on their values
x = {'Current': 'low_risk'}   
loans_df = loans_df.replace(x)
loans_df['loan_status'].value_counts()
# Out:
# low_risk              89971
# In Grace Period         219
# Late (16-30 days)       132
# Late (31-120 days)      123
# Name: loan_status, dtype: int64

# %%
x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period'], 'high_risk')    
loans_df = loans_df.replace(x)
loans_df['loan_status'].value_counts()
# Out:
# low_risk     89971
# high_risk      474
# Name: loan_status, dtype: int64

# %%
# check the percentage of high_risk loans using ratio high_risk / low_risk * 100
loan_status_value_counts = loans_df['loan_status'].value_counts()
percent_high_risk_loans = round(loan_status_value_counts[1]/loan_status_value_counts[0] * 100 ,2)
percent_high_risk_loans
print(f"There are {percent_high_risk_loans}% high risk loans")
# Out:
# 0.53

# %%
loans_df.shape
# Out:
# (90445, 74)

# %% [markdown]
# ### Data Cleaning: convert data to numeric, put into correct format (decimal vs. percentage), remove any unit symbols (i.e. int_rate - %)

# %%
# convert interest rate to numerical
loans_df['int_rate'] = loans_df['int_rate'].str.replace('%', '')
loans_df['int_rate'] = loans_df['int_rate'].astype('float') / 100
loans_df.head()
# Out:
#      loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 82     20000.0    0.2250       769.00           RENT     75000.0
# 93     10500.0    0.1719       375.35           RENT     66000.0
# 99     25000.0    0.2000       929.09       MORTGAGE    105000.0
# 132    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 133    10000.0    0.1640       353.55           RENT     92000.0
#
#     verification_status   issue_d loan_status    dti  delinq_2yrs  ...  \
# 82         Not Verified  Mar-2019    low_risk  24.37          0.0  ...
# 93      Source Verified  Mar-2019    low_risk  27.24          0.0  ...
# 99             Verified  Mar-2019    low_risk  20.23          0.0  ...
# 132            Verified  Mar-2019    low_risk  24.26          0.0  ...
# 133            Verified  Mar-2019    low_risk  31.44          0.0  ...
#
#      num_sats  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 82        8.0                 0.0                 1.0           100.0
# 93        8.0                 0.0                 3.0            85.7
# 99       17.0                 0.0                 6.0            91.2
# 132       8.0                 0.0                 4.0            66.7
# 133      10.0                 0.0                 1.0           100.0
#
#      percent_bc_gt_75 pub_rec_bankruptcies  tot_hi_cred_lim  \
# 82              100.0                  0.0          77797.0
# 93              100.0                  0.0          65687.0
# 99               50.0                  1.0         271427.0
# 132              50.0                  0.0          60644.0
# 133              50.0                  1.0          99506.0
#
#      total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# 82             55014.0         47000.0                     30797.0
# 93             38199.0          2000.0                     61987.0
# 99             60641.0         41200.0                     49197.0
# 132            45684.0          7500.0                     43144.0
# 133            68784.0         19700.0                     76506.0
#
# [5 rows x 74 columns]

# %%
# examine dtypes
loans_df.info()

# note there are several dtype with object that will need to recast as a numeric
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90445 entries, 82 to 115674
# Data columns (total 74 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   loan_amnt                   90445 non-null  float64
#  1   int_rate                    90445 non-null  float64
#  2   installment                 90445 non-null  float64
#  3   home_ownership              90445 non-null  object
#  4   annual_inc                  90445 non-null  float64
#  5   verification_status         90445 non-null  object
#  6   issue_d                     90445 non-null  object
#  7   loan_status                 90445 non-null  object
#  8   dti                         90445 non-null  float64
#  9   delinq_2yrs                 90445 non-null  float64
#  10  inq_last_6mths              90445 non-null  float64
#  11  open_acc                    90445 non-null  float64
#  12  pub_rec                     90445 non-null  float64
#  13  revol_bal                   90445 non-null  float64
#  14  total_acc                   90445 non-null  float64
#  15  initial_list_status         90445 non-null  object
#  16  out_prncp                   90445 non-null  float64
#  17  out_prncp_inv               90445 non-null  float64
#  18  total_pymnt                 90445 non-null  float64
#  19  total_pymnt_inv             90445 non-null  float64
#  20  total_rec_prncp             90445 non-null  float64
#  21  total_rec_int               90445 non-null  float64
#  22  total_rec_late_fee          90445 non-null  float64
#  23  last_pymnt_amnt             90445 non-null  float64
#  24  next_pymnt_d                90445 non-null  object
#  25  collections_12_mths_ex_med  90445 non-null  float64
#  26  application_type            90445 non-null  object
#  27  tot_coll_amt                90445 non-null  float64
#  28  tot_cur_bal                 90445 non-null  float64
#  29  open_acc_6m                 90445 non-null  float64
#  30  open_act_il                 90445 non-null  float64
#  31  open_il_12m                 90445 non-null  float64
#  32  open_il_24m                 90445 non-null  float64
#  33  mths_since_rcnt_il          90445 non-null  float64
#  34  total_bal_il                90445 non-null  float64
#  35  open_rv_12m                 90445 non-null  float64
#  36  open_rv_24m                 90445 non-null  float64
#  37  max_bal_bc                  90445 non-null  float64
#  38  all_util                    90445 non-null  float64
#  39  total_rev_hi_lim            90445 non-null  float64
#  40  inq_fi                      90445 non-null  float64
#  41  total_cu_tl                 90445 non-null  float64
#  42  inq_last_12m                90445 non-null  float64
#  43  acc_open_past_24mths        90445 non-null  float64
#  44  avg_cur_bal                 90445 non-null  float64
#  45  bc_open_to_buy              90445 non-null  float64
#  46  bc_util                     90445 non-null  float64
#  47  chargeoff_within_12_mths    90445 non-null  float64
#  48  delinq_amnt                 90445 non-null  float64
#  49  mo_sin_old_il_acct          90445 non-null  float64
#  50  mo_sin_old_rev_tl_op        90445 non-null  float64
#  51  mo_sin_rcnt_rev_tl_op       90445 non-null  float64
#  52  mo_sin_rcnt_tl              90445 non-null  float64
#  53  mort_acc                    90445 non-null  float64
#  54  mths_since_recent_bc        90445 non-null  float64
#  55  num_accts_ever_120_pd       90445 non-null  float64
#  56  num_actv_bc_tl              90445 non-null  float64
#  57  num_actv_rev_tl             90445 non-null  float64
#  58  num_bc_sats                 90445 non-null  float64
#  59  num_bc_tl                   90445 non-null  float64
#  60  num_il_tl                   90445 non-null  float64
#  61  num_op_rev_tl               90445 non-null  float64
#  62  num_rev_accts               90445 non-null  float64
#  63  num_rev_tl_bal_gt_0         90445 non-null  float64
#  64  num_sats                    90445 non-null  float64
#  65  num_tl_90g_dpd_24m          90445 non-null  float64
#  66  num_tl_op_past_12m          90445 non-null  float64
#  67  pct_tl_nvr_dlq              90445 non-null  float64
#  68  percent_bc_gt_75            90445 non-null  float64
#  69  pub_rec_bankruptcies        90445 non-null  float64
#  70  tot_hi_cred_lim             90445 non-null  float64
#  71  total_bal_ex_mort           90445 non-null  float64
#  72  total_bc_limit              90445 non-null  float64
#  73  total_il_high_credit_limit  90445 non-null  float64
# dtypes: float64(67), object(7)
# memory usage: 51.8+ MB

# %%
# many rows have been removed therefore the index will be reset using reset_index
loans_df.reset_index(inplace=True, drop=True)

loans_df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    20000.0    0.2250       769.00           RENT     75000.0
# 1    10500.0    0.1719       375.35           RENT     66000.0
# 2    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 3    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 4    10000.0    0.1640       353.55           RENT     92000.0
#
#   verification_status   issue_d loan_status    dti  delinq_2yrs  ...  \
# 0        Not Verified  Mar-2019    low_risk  24.37          0.0  ...
# 1     Source Verified  Mar-2019    low_risk  27.24          0.0  ...
# 2            Verified  Mar-2019    low_risk  20.23          0.0  ...
# 3            Verified  Mar-2019    low_risk  24.26          0.0  ...
# 4            Verified  Mar-2019    low_risk  31.44          0.0  ...
#
#    num_sats  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0       8.0                 0.0                 1.0           100.0
# 1       8.0                 0.0                 3.0            85.7
# 2      17.0                 0.0                 6.0            91.2
# 3       8.0                 0.0                 4.0            66.7
# 4      10.0                 0.0                 1.0           100.0
#
#    percent_bc_gt_75 pub_rec_bankruptcies  tot_hi_cred_lim  total_bal_ex_mort  \
# 0             100.0                  0.0          77797.0            55014.0
# 1             100.0                  0.0          65687.0            38199.0
# 2              50.0                  1.0         271427.0            60641.0
# 3              50.0                  0.0          60644.0            45684.0
# 4              50.0                  1.0          99506.0            68784.0
#
#    total_bc_limit  total_il_high_credit_limit
# 0         47000.0                     30797.0
# 1          2000.0                     61987.0
# 2         41200.0                     49197.0
# 3          7500.0                     43144.0
# 4         19700.0                     76506.0
#
# [5 rows x 74 columns]

# %%
loans_df.shape
# Out:
# (90445, 74)

# %% [markdown]
# ### Save the loans_df dataframe as a csv for access to others and for use in pre-processing
# Note: The result of feature selection / engineering and data cleaning is the trasformation of a dataset from shape of 115,674, 144 to one of 71,027, 76. This is a loss of 68 columns and 44,648 rows of data

# %%
# save our loans_df as clean_loans_df csv file
clean_loans_df = loans_df

# df.to_csv(index=False)
clean_loans_df.to_csv("./Data/clean_loans.csv",index=False)

# %% [markdown]
# ## Additional EDA: Visual Analysis

# %%
# g = sns.PairGrid(clean_loans_df, hue="loan_status")
# g.map_diag(sns.histplot)
# g.map_offdiag(sns.scatterplot)
# g.add_legend()

# %% [markdown]
# ### check the correlation between different variables

# %%
# check the correlation between different variables
plt.figure(figsize=(25,25))
sns.heatmap(clean_loans_df.corr(),cbar=True,annot=True)
# set cmap='Blues' or other color if preferred

# Note: 
# * Positive Correlation is dark
# * Negative Correlation is lighter
# * White is the identity matrix
# Out:
# <AxesSubplot:>

# %% [markdown]
# Note:
# * Positive Correlation is dark
# * Negative Correlation is lighter
# * White is the identity matrix
#
# ### Follow-up: This would be good to review using the feature_importance_ dataframe from BalancedRandomForestClassifier

# %% [markdown]
# #### Explore high_risk vs low_risk loans

# %%
#### Explore the sum of high_risk loans to low_risk loans using groupby and sum as the method of aggregation
# keep just the loan_amnt column
loans_grouped = loans_df.groupby("loan_status").sum()['loan_amnt']
loans_grouped = loans_grouped.apply(lambda x: format(x, 'f'))
# Out:
# loan_status
# high_risk       7823350.000000
# low_risk     1516234400.000000
# Name: loan_amnt, dtype: object

# %%
# express scientific notation as a float
# contrib_df["AMNT"].describe().apply(lambda x: format(x, 'f'))
loans_grouped.apply(lambda x: format(x, 'f'))

# even reducing a small reduction in high_risk loans might be beneficial
# Out:
# loan_status
# high_risk       7823350.000000
# low_risk     1516234400.000000
# Name: loan_amnt, dtype: object

# %% [markdown]
# #### Explore variable distribution using a histogram

# %%
# what is the distribution of int_rate?
sns.histplot(clean_loans_df.int_rate, bins=15)
# Out:
# <AxesSubplot:xlabel='int_rate', ylabel='Count'>

# %%
# what is the distribution of loans by loan_amnt?
sns.histplot(clean_loans_df.loan_amnt, bins=10)
plt.title("histogram of loan amounts ($)")
# Out:
# Text(0.5, 1.0, 'histogram of loan amounts ($)')

# %% [markdown]
# #### Explore the relationship between multiple varialbes - using a stacked bar chart

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    clean_loans_df,
    x="loan_amnt", hue="home_ownership",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([5000, 10000, 20000, 30000, 40000])
# Out:
# [<matplotlib.axis.XTick at 0x1b6eb9afd88>,
#  <matplotlib.axis.XTick at 0x1b6eb9a87c8>,
#  <matplotlib.axis.XTick at 0x1b6eba66948>,
#  <matplotlib.axis.XTick at 0x1b6ebc86708>,
#  <matplotlib.axis.XTick at 0x1b6ebc8fbc8>]

# %% [markdown]
# #### Explore the relationship between multiple varialbes - using a scatter plot

# %%
# what is the relationship between loan_amnt and int_rate
plt.figure(figsize=(10,10))
sns.scatterplot(data=clean_loans_df, x='loan_amnt',y='int_rate', hue="loan_status")
#plt.scatter(x='total_rec_int',y='last_pymnt_amnt',data=clean_loans_df)
plt.xlabel('loan_amnt')
plt.ylabel('int_rate')
# Out:
# Text(0, 0.5, 'int_rate')

# %% [markdown]
# #### Compare the distribution of a variable (int_rate) by another discrete factor (loan_status)  - using a boxplot

# %%
# what is the distribution of int_rate to loan_status?
# view as a box plot 
ax = sns.boxplot(x="loan_status", y="int_rate", data=clean_loans_df)

# %% [markdown]
# #### Explore the relationship between a continuos variable (loan_amt) and a discrete variable (loan_status) by a third discrete variable (home_ownership) - a violin plot

# %%
# what is the distribution of loan amounts (last_pymnt_amnt) loan_status by home_ownership?
# view as a violin plot
ax = sns.violinplot(x="loan_status", y="loan_amnt", hue='home_ownership', data=clean_loans_df)
# ax = sns.boxplot(x="loan_status", y="loan_amnt", hue='home_ownership', data=clean_loans_df)

# %% [markdown]
# #### Other plot ideas

# %%
# What is the difference amont risk by issued date 
clean_loans_df["issue_d"].value_counts()
# Out:
# Jan-2019    40591
# Feb-2019    33758
# Mar-2019    16096
# Name: issue_d, dtype: int64

# %%
sns.set_theme(style="whitegrid")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=clean_loans_df, x="issue_d", y="loan_amnt", hue="loan_status",
               split=True, inner="quart", linewidth=1,
               palette={"low_risk": "b", "high_risk": ".85"})
sns.despine(left=True)

# %% [markdown]
# #### Examine the relationship between two variables using a scatter plot

# %%
# what is the relationship between loan_amnt and int_rate
plt.figure(figsize=(10,10))
sns.scatterplot(data=clean_loans_df, x='total_rec_int',y='last_pymnt_amnt')
#plt.scatter(x='total_rec_int',y='last_pymnt_amnt',data=clean_loans_df)
plt.xlabel('total_rec_int')
plt.ylabel('last_pymnt_amnt')
# Out:
# Text(0, 0.5, 'last_pymnt_amnt')

# %%
# what is the distribution of late fees received to date to loan_status?
# view as a box plot 
ax = sns.boxplot(x="loan_status", y="total_rec_late_fee", data=clean_loans_df)

# %%
# from the seaborn gallery
# https://seaborn.pydata.org/examples/faceted_histogram.html
sns.set_theme(style="darkgrid")

sns.displot(
    clean_loans_df, x="total_pymnt", col="issue_d", row="loan_status",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %%
# relationship between int rate and total payment by issue date
sns.set_theme(style="white")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="total_pymnt", y="total_rec_int", hue="loan_status", size="loan_amnt",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=clean_loans_df)

# %% [markdown]
# ## End Exploritory Data Analysis
